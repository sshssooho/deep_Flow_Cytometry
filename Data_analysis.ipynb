# %%
import os
import fcsparser

# %%
os.listdir('../../data/')
# Out:
# ['[XN-20^11602][00-19 (Build 9)][Fcs][20150102_065453][BACKGROUNDCHECK][PLT-F].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_065453][BACKGROUNDCHECK][RET].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_065453][BACKGROUNDCHECK][WDF].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_065453][BACKGROUNDCHECK][WNR].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_065453][BACKGROUNDCHECK][WPC].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_071329][QC-43071101][PLT-F].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_071329][QC-43071101][RET].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_071329][QC-43071101][WDF].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_071329][QC-43071101][WNR].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_071329][QC-43071101][WPC].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_071445][QC-43071102][PLT-F].fcs',
#  '[XN-20^11602][00-19 (Build 9)][Fcs][20150102_071445][QC-43071102][RET].fcs',
# ...

# %%
path = '../../data/[XN-20^11602][00-19 (Build 9)][Fcs][20150102_065453][BACKGROUNDCHECK][PLT-F].fcs'
meta, data = fcsparser.parse(path, reformat_meta=True)

# %%
meta
# Out:
# {'__header__': {'FCS format': b'FCS3.0',
#   'text start': 58,
#   'text end': 2909,
#   'data start': 2910,
#   'data end': 4925,
#   'analysis start': 0,
#   'analysis end': 0},
#  '$BEGINANALYSIS': '0000000000',
#  '$BEGINDATA': '0000002910',
#  '$BEGINSTEXT': '0000000058',
#  '$BYTEORD': '1,2,3,4',
#  '$DATATYPE': 'I',
#  '$ENDANALYSIS': '0000000000',
#  '$ENDDATA': '0000004925',
#  '$ENDSTEXT': '0000002909',
#  '$MODE': 'L',
#  '$NEXTDATA': 0,
#  '$TOT': 504,
#  '$PAR': 4,
#  '$CELLS': 'WB',
#  '$COM': 'Sysmex',
#  '$CYT': 'XN-20',
#  '$CYTSN': '11602',
#  '$DATE': '02-JAN-2015',
#  '$ETIM': '06:54:53',
#  '$FIL': '[XN-20^11602][00-17_6][20150102_065453][       BACKGROUNDCHECK].116',
#  '$ORIGINALITY': 'Original',
#  '$SMNO': 'BACKGROUNDCHECK',
#  '$SYS': 'Windows 7',
#  '$Sysmex_WBC': '0.00 10^3/uL',
#  '$Sysmex_RBC': '0.00 10^6/uL',
#  '$Sysmex_HGB': '0.0 g/dL',
#  '$Sysmex_HCT': '0.0 %',
#  '$Sysmex_MCV': '---- fL',
#  '$Sysmex_MCH': '---- pg',
# ...

# %%
data
# Out:
#      Side Fluorescence Signal  Forward Scatter Signal  Side Scatter Signal  \
# 0                         9.0                    57.0                127.0
# 1                         3.0                    38.0                 25.0
# 2                         4.0                    84.0                 78.0
# 3                         3.0                    44.0                 39.0
# 4                         4.0                    38.0                 34.0
# ..                        ...                     ...                  ...
# 499                       4.0                    53.0                 44.0
# 500                       0.0                    64.0                 39.0
# 501                      11.0                    65.0                 51.0
# 502                       0.0                    34.0                 36.0
# 503                       3.0                    68.0                 64.0
#
#      Forward Scatter Pulse Width Signal
# ...

# %%
path = '../../data/[XN-20^11602][00-19 (Build 9)][Fcs][20150102_065453][BACKGROUNDCHECK][RET].fcs'
meta, data = fcsparser.parse(path, reformat_meta=True)
data
# Out:
#      Side Fluorescence Signal  Forward Scatter Signal  Side Scatter Signal  \
# 0                         0.0                     8.0                  5.0
# 1                         0.0                    10.0                  4.0
# 2                         0.0                     1.0                  2.0
# 3                         0.0                     4.0                  2.0
# 4                         0.0                     4.0                  2.0
# ..                        ...                     ...                  ...
# 97                        0.0                     1.0                  1.0
# 98                        0.0                     8.0                 41.0
# 99                        0.0                     1.0                  1.0
# 100                       0.0                     7.0                  3.0
# 101                       0.0                     1.0                  2.0
#
# ...
